# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.Graph()

G.add_edge(0,1)
G.add_edge(0,5)
G.add_edge(0,6)
G.add_edge(3,4)
G.add_edge(5,4)
G.add_edge(6,3)
G.add_edge(2,3)
G.add_edge(1,6)
G.add_edge(2,1)
G.add_edge(2,3)
G.add_edge(6,2)
G.add_edge(6,4)

nx.draw(G, with_labels = 1)
